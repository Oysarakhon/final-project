# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
sample_data = pd.read_csv('dataset.csv')

# %%
sample_data
# Out:
#      world_rank                            institution         country  \
# 0             1                     Harvard University             USA
# 1             2  Massachusetts Institute of Technology             USA
# 2             3                    Stanford University             USA
# 3             4                University of Cambridge  United Kingdom
# 4             5     California Institute of Technology             USA
# ..          ...                                    ...             ...
# 395          96                   University of Zurich     Switzerland
# 396          97               Arizona State University             USA
# 397          98                      Yonsei University     South Korea
# 398          99                     University of Oslo          Norway
# 399         100                      Kyushu University           Japan
#
#      national_rank  quality_of_education  alumni_employment  \
# 0                1                     7                  9
# 1                2                     9                 17
# 2                3                    17                 11
# 3                1                    10                 24
# 4                4                     2                 29
# ..             ...                   ...                ...
# 395              4                   115                389
# 396             55                   367                455
# 397              2                   367                 45
# 398              1                    53                286
# 399              7                   367                 49
#
#      quality_of_faculty  publications  influence  citations  broad_impact  \
# 0                     1             1          1          1           NaN
# 1                     3            12          4          4           NaN
# 2                     5             4          2          2           NaN
# 3                     4            16         16         11           NaN
# 4                     7            37         22         22           NaN
# ..                  ...           ...        ...        ...           ...
# 395                  85            56         46         68          56.0
# 396                  66           143         85         76         140.0
# 397                 218           140        326        321         235.0
# 398                  40           106        134        101         102.0
# 399                 218           152        182        264         200.0
#
#      patents   score  year
# 0          5  100.00  2012
# 1          1   91.67  2012
# 2         15   89.50  2012
# 3         50   86.17  2012
# 4         18   85.21  2012
# ..       ...     ...   ...
# 395      137   51.14  2015
# 396       21   51.13  2015
# 397       23   51.02  2015
# 398      302   50.81  2015
# 399       37   50.60  2015
#
# [400 rows x 14 columns]

# %%
dk=df[['world_rank','institution', 'year']]
dk.head()
# Out:
#    world_rank                            institution  year
# 0           1                     Harvard University  2012
# 1           2  Massachusetts Institute of Technology  2012
# 2           3                    Stanford University  2012
# 3           4                University of Cambridge  2012
# 4           5     California Institute of Technology  2012

# %%
wr_sort = dk.sort_values('world_rank')
wr_sort = wr_sort.loc[0:309,['world_rank','institution','year']]
wr_sort
# Out:
#      world_rank                            institution  year
# 0             1                     Harvard University  2012
# 200           1                     Harvard University  2014
# 300           1                     Harvard University  2015
# 100           1                     Harvard University  2013
# 1             2  Massachusetts Institute of Technology  2012
# 201           2                    Stanford University  2014
# 101           2                    Stanford University  2013
# 301           2                    Stanford University  2015
# 302           3  Massachusetts Institute of Technology  2015
# 202           3  Massachusetts Institute of Technology  2014
# 102           3                   University of Oxford  2013
# 2             3                    Stanford University  2012
# 203           4                University of Cambridge  2014
# 3             4                University of Cambridge  2012
# 103           4  Massachusetts Institute of Technology  2013
# 303           4                University of Cambridge  2015
# 204           5                   University of Oxford  2014
# 304           5                   University of Oxford  2015
# 4             5     California Institute of Technology  2012
# 104           5                University of Cambridge  2013
# 305           6                    Columbia University  2015
# 205           6                    Columbia University  2014
# 105           6                    Columbia University  2013
# 5             6                   Princeton University  2012
# 6             7                   University of Oxford  2012
# 306           7     University of California, Berkeley  2015
# 106           7     University of California, Berkeley  2013
# 206           7     University of California, Berkeley  2014
# 307           8                  University of Chicago  2015
# 107           8                   Princeton University  2013
# 7             8                        Yale University  2012
# 207           8                  University of Chicago  2014
# 8             9                    Columbia University  2012
# 208           9                   Princeton University  2014
# 108           9                  University of Chicago  2013
# 308           9                   Princeton University  2015
# 209          10                        Yale University  2014
# 109          10                        Yale University  2013
# 9            10     University of California, Berkeley  2012
# 309          10                     Cornell University  2015

# %%
ysort = wr_sort.sort_values('year')
ysort.loc[:, ['world_rank','institution','year']]
ysort
# Out:
#      world_rank                            institution  year
# 0             1                     Harvard University  2012
# 8             9                    Columbia University  2012
# 1             2  Massachusetts Institute of Technology  2012
# 7             8                        Yale University  2012
# 6             7                   University of Oxford  2012
# 5             6                   Princeton University  2012
# 2             3                    Stanford University  2012
# 9            10     University of California, Berkeley  2012
# 3             4                University of Cambridge  2012
# 4             5     California Institute of Technology  2012
# 109          10                        Yale University  2013
# 108           9                  University of Chicago  2013
# 107           8                   Princeton University  2013
# 106           7     University of California, Berkeley  2013
# 105           6                    Columbia University  2013
# 104           5                University of Cambridge  2013
# 103           4  Massachusetts Institute of Technology  2013
# 100           1                     Harvard University  2013
# 102           3                   University of Oxford  2013
# 101           2                    Stanford University  2013
# 204           5                   University of Oxford  2014
# 200           1                     Harvard University  2014
# 209          10                        Yale University  2014
# 208           9                   Princeton University  2014
# 207           8                  University of Chicago  2014
# 201           2                    Stanford University  2014
# 206           7     University of California, Berkeley  2014
# 202           3  Massachusetts Institute of Technology  2014
# 205           6                    Columbia University  2014
# 203           4                University of Cambridge  2014
# 303           4                University of Cambridge  2015
# 307           8                  University of Chicago  2015
# 306           7     University of California, Berkeley  2015
# 302           3  Massachusetts Institute of Technology  2015
# 305           6                    Columbia University  2015
# 300           1                     Harvard University  2015
# 308           9                   Princeton University  2015
# 304           5                   University of Oxford  2015
# 301           2                    Stanford University  2015
# 309          10                     Cornell University  2015

# %%
inst_count=wr_sort['institution'].value_counts()
inst_count.iloc[0:10]
# Out:
# University of California, Berkeley       4
# Massachusetts Institute of Technology    4
# University of Cambridge                  4
# Stanford University                      4
# Harvard University                       4
# Columbia University                      4
# University of Oxford                     4
# Princeton University                     4
# University of Chicago                    3
# Yale University                          3
# Name: institution, dtype: int64

# %%
country = df[['country']]
country = country.sort_values('country')
count = country.value_counts()
count = count.iloc[:10]
count
# Out:
# country
# USA               223
# United Kingdom     29
# Japan              26
# France             18
# Switzerland        16
# Israel             14
# Canada             13
# Germany            11
# Australia           8
# Netherlands         6
# dtype: int64

# %%
my_plot = count.plot(kind='bar', figsize=(15, 10))

font1 = {'family':'serif','color':'aquamarine','size':20}
font2 = {'family':'serif','color':'magenta','size':15}
my_plot.set_xlabel("Countries", fontdict = font2)
my_plot.set_ylabel("Frequency occurence", fontdict = font2)
plt.title('10 most occured countries 2012-2015', fontdict = font1, loc = 'center')
plt.tight_layout()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from PIL import Image
img_1 = Image.open('top')
img_1
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=575x693 at 0xEDC2460>

# %%
data = pd.read_csv('uni.csv')

# %%
data
# Out:
#          2021 WUR Rank 2021  \
# 0          1�            13
# 1          2�           27�
# 2          3�            55
# 3          4�          48��
# 4          5�          52��
# ..        ...           ...
# 149   101-150       751-800
# 150  101-150�      801-1000
# 151   101-150      801-1000
# 152   101-150      801-1000
# 153   101-150      801-1000
#
#                                            Institution        Location
# 0               Nanyang Technological University (NTU)       Singapore
# 1    The Hong Kong University of Science and Techno...   Hong Kong SAR
# 2    KAIST - Korea Advanced Institute of Science an...     South Korea
# 3                         City University of Hong Kong   Hong Kong SAR
# 4            Universit? PSL (Paris Sciences & Lettres)          France
# ..                                                 ...             ...
# 149                      London South Bank University�  United Kingdom
# 150           Universidad Aut?noma Metropolitana (UAM)          Mexico
# 151  Vietnam National University - Ho Chi Minh City...         Vietnam
# 152                    Universit? degli Studi Roma Tre           Italy
# 153                        Vietnam National University             NaN
#
# [154 rows x 4 columns]

# %%
us = data[data.Location == 'United Kingdom']

# %%
us
# Out:
#          2021 WUR Rank 2021                    Institution        Location
# 53         50           383      Oxford Brookes University  United Kingdom
# 91      81-90       541-550            Coventry University  United Kingdom
# 106  101-150�       601-650              Ulster University  United Kingdom
# 107   101-150       601-650      University of Portsmouth�  United Kingdom
# 124  101-150�       701-750    University of Huddersfield�  United Kingdom
# 128   101-150       701-750           Middlesex University  United Kingdom
# 133  101-150�       701-750       University of Greenwich�  United Kingdom
# 146   101-150      751-800�        Bournemouth University�  United Kingdom
# 149   101-150       751-800  London South Bank University�  United Kingdom

# %%
sin = data[data.Location == 'Singapore']

# %%
sin
# Out:
#      2021 WUR Rank 2021                             Institution   Location
# 0      1�            13  Nanyang Technological University (NTU)  Singapore
# 84  81-90       511-520        Singapore Management University�  Singapore

# %%
from PIL import Image
img = Image.open('yo')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=605x340 at 0xE312250>

# %%
first = pd.read_csv('best1.csv')

# %%
first
# Out:
#               2020 rank;2019 rank;University;Country
# 0            1;1;University of Oxford;United Kingdom
# 1  2;5;California Institute of Technology;United ...
# 2         3;2;University of Cambridge;United Kingdom
# 3              4;3;Stanford University;United States
# 4  5;4;Massachusetts Institute of Technology;Unit...
# 5             6;7;Princeton University;United States
# 6               7;6;Harvard University;United States
# 7                  8;8;Yale University;United States
# 8           9;10;University of Chicago;United States
# 9        10;9;Imperial College London;United Kingdom

# %%
second = pd.read_csv('best2.csv')

# %%
second
# Out:
#    Country/region;Number of;Best university;Best rank
# 0                                     ;universities;;
# 1   United States;60;California Institute of Techn...
# 2            United Kingdom;28;University of Oxford;1
# 3                            Germany;23;LMU Munich;32
# 4             Australia;11;University of Melbourne;32
# 5   Netherlands;11;Wageningen University & Researc...
# 6                   Canada;7;University of Toronto;18
# 7                      China;7;Tsinghua University;23
# 8                         Switzerland;7;ETH Zurich;13
# 9          South Korea;6;Seoul National University;64
# 10  France;5;Paris Sciences et Lettres � PSL Resea...
# 11             Hong Kong;5;University of Hong Kong;35
# 12                   Sweden;5;Karolinska Institute;41

# %%
from PIL import Image
img = Image.open('ranking2')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=785x373 at 0xE474088>
