# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
x = [1, 2, 3]
y = [4, 5, 6]
plt.plot(x,y)
plt.show()

# %%
sample_data = pd.read_csv('countries.csv')

# %%
sample_data
# Out:
#             country          year population;
# Afghanistan    1952  8425333;2021      198502
# Afghanistan    1957      9240934;         NaN
# Afghanistan    1962     10267083;         NaN
# Afghanistan    1967     11537966;         NaN
# Afghanistan    1972     13079460;         NaN
# ...             ...           ...         ...
# Zimbabwe       1987      9216418;         NaN
# Zimbabwe       1992     10704340;         NaN
# Zimbabwe       1997     11404948;         NaN
# Zimbabwe       2002     11926563;         NaN
# Zimbabwe       2007     12311143;         NaN
#
# [1704 rows x 3 columns]

# %%
import pandas as pd
from matplotlib import pyplot as plt
x = [1, 2, 3]
y = [0, 5, 10]
z = [1, 5, 0]
plt.plot(x,y)
plt.plot(x,z)
plt.title("TOP universities around the world")
plt.xlabel("x")
plt.ylabel("y and z")
plt.legend(["Harvard UNiversity", "MIT"])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as num
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from PIL import Image
img = Image.open('asia')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=900x742 at 0xC8F13B8>

# %%
from PIL import Image
img_1 = Image.open('top')
img_1
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=575x693 at 0xEDC2460>
